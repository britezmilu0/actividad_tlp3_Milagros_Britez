# %% [markdown]
# # Actividad - Trabajando con Series de Pandas.
# ## Criterios de evaluación.
#
# * Se deben utilizar nombres de variables descriptivos y claros (Utilizar la nomeclatura correspondiente para los nombres de variables).
# * Comentarios claros y concisos que expliquen el propósito de cada sección del código.
# * Utilizar mensajes de commit **descriptivos**. (Puedes utilizar la extension CONVENTIONAL COMMIT de VS-CODE).
# * Entrega en tiempo y forma.
# * Todo el código desarrollado debe ser subido a un repositorio en GitHub (el nombre del repositorio de seguir la siguiente estructura: actividad_tlp3_nombre_apellido).
# * Para resolver las actividades se debe insertar casillas de codigo entre cada actividad del cuaderno de Jupyter
#
# ### ¡Importante!
# **El incumplimiento de los criterios de evaluación restará puntos en la nota final del práctico!**

# %% [markdown]
# ### **Actividad 1:**
#
# Crear Series desde diferentes estructuras.
# * Crea una Series con los números del 1 al 5
# * Crea una Series a partir de un diccionario con nombres de países como claves y sus capitales como valores.
#
# Descriptción de elección de mi código:
# Creo una serie de números del 1 al 5, luego creo un dicccionario con paises y capitales.

# %%
import pandas as pd

numeros_serie = pd.Series([1, 2, 3, 4, 5])
print("Serie de números:")
print(numeros_serie)


paises_capitales = {
    "Argentina": "Buenos Aires",
    "Brasil": "Brasilia",
    "Chile": "Santiago"
}
capitales_serie = pd.Series(paises_capitales)
print("\nSerie de países y capitales:")
print(capitales_serie)
# Out:
# Serie de números:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#
# Serie de países y capitales:
# Argentina    Buenos Aires
# Brasil           Brasilia
# Chile            Santiago
# dtype: object

# %% [markdown]
# ### **Actividad 2:**
# Acceso y selección de elementos.
# * Usa una Series con tareas (que haceres cotidianos) de una semana
# * Accede a diferentes elementos a elección.
# * Cambia los valores de los dias pares.
#
# Descripción: creo una serie de tareas de una semana, accedo a elementos especificos y por ultimo cambio los valores de dias pares.

# %%
# todo:
[ ]


tareas_semana = pd.Series(
    ["Limpieza", "Compras", "Cocinar", "Estudiar", "Ejercicio", "Leer", "Dormir"],
    index=["Lunes", "Martes", "Miércoles", "Jueves", "Viernes", "Sábado", "Domingo"]
)
print("Tareas originales:")
print(tareas_semana)


print("\nAcceso a Lunes y Sábado:")
print(tareas_semana[["Lunes", "Sábado"]])


tareas_semana.iloc[[1, 3, 5]] = "Descanso"
print("\nTareas actualizadas (días pares cambiados):")
print(tareas_semana)
# Out:
# Tareas originales:
# Lunes         Limpieza
# Martes         Compras
# Miércoles      Cocinar
# Jueves        Estudiar
# Viernes      Ejercicio
# Sábado            Leer
# Domingo         Dormir
# dtype: object
#
# Acceso a Lunes y Sábado:
# Lunes     Limpieza
# Sábado        Leer
# dtype: object
#
# Tareas actualizadas (días pares cambiados):
# Lunes         Limpieza
# Martes        Descanso
# Miércoles      Cocinar
# Jueves        Descanso
# Viernes      Ejercicio
# Sábado        Descanso
# Domingo         Dormir
# dtype: object

# %% [markdown]
# ### **Actividad 3:**
# Operaciones aritméticas.
# * Realiza las operaciones basicas con 2 series cuales quieran.
# * Eleva los valores de la primer serie a 3 potencias difetentes.
#
# Descripción: creo dos series con valores númericos, realizo las operaciones suma, resta, multiplicación y división. Por último elevo la primera serie a tres potencias distintas

# %%
# todo:
[ ]



serie1 = pd.Series([10, 20, 30, 40])
serie2 = pd.Series([1, 2, 3, 4])
print("Serie 1:")
print(serie1)
print("Serie 2:")
print(serie2)


suma = serie1 + serie2
resta = serie1 - serie2
multiplicacion = serie1 * serie2
division = serie1 / serie2
print("\nOperaciones básicas:")
print("Suma:", suma)
print("Resta:", resta)
print("Multiplicación:", multiplicacion)
print("División:", division)


potencia1 = serie1 ** 2
potencia2 = serie1 ** 3
potencia3 = serie1 ** 4
print("\nPotencias de la Serie 1:")
print("Al cuadrado:", potencia1)
print("Al cubo:", potencia2)
print("A la cuarta:", potencia3)
# Out:
# Serie 1:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# Serie 2:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
#
# Operaciones básicas:
# Suma: 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64
# Resta: 0     9
# 1    18
# 2    27
# 3    36
# dtype: int64
# Multiplicación: 0     10
# 1     40
# 2     90
# 3    160
# dtype: int64
# División: 0    10.0
# 1    10.0
# 2    10.0
# 3    10.0
# dtype: float64
#
# Potencias de la Serie 1:
# Al cuadrado: 0     100
# 1     400
# 2     900
# 3    1600
# dtype: int64
# Al cubo: 0     1000
# 1     8000
# 2    27000
# 3    64000
# dtype: int64
# A la cuarta: 0      10000
# 1     160000
# 2     810000
# 3    2560000
# dtype: int64

# %% [markdown]
# ### **Actividad 4:**
# Filtrado con condiciones.
# * Crea una Series de edades de 10 personas.
# * Muestra solo a los mayores de 18.
# * Reemplaza a los menores por "Menor de edad".
#
# Descripción: creo una serie de edades de 10 personas, muestro solo los mayores de 18 años y por utlimo reemplazo menores de edad por menor de edad

# %%
# todo:
[ ]


edades = pd.Series([15, 22, 17, 19, 25, 16, 30, 14, 21, 28])
print("Edades originales:")
print(edades)


mayores_18 = edades[edades > 18]
print("\nMayores de 18:")
print(mayores_18)


edades[edades <= 18] = "Menor de edad"
print("\nEdades actualizadas:")
print(edades)
# Out:
# Edades originales:
# 0    15
# 1    22
# 2    17
# 3    19
# 4    25
# 5    16
# 6    30
# 7    14
# 8    21
# 9    28
# dtype: int64
#
# Mayores de 18:
# 1    22
# 3    19
# 4    25
# 6    30
# 8    21
# 9    28
# dtype: int64
#
# Edades actualizadas:
# 0    Menor de edad
# 1               22
# 2    Menor de edad
# 3               19
# 4               25
# 5    Menor de edad
# 6               30
# 7    Menor de edad
# 8               21
# 9               28
# dtype: object
# C:\Users\Asus\AppData\Local\Temp\ipykernel_33408\900778781.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Menor de edad' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   edades[edades <= 18] = "Menor de edad"

# %% [markdown]
# ### Actividad 5:
# Estadísticas básicas.
#
# * Crea una Series con las notas de 10 estudiantes.
# * Calcula la media, mediana, desviación estándar y máximo.
# * Muestra cuántos estudiantes aprobaron si el mínimo para aprobar es 6.
# * Ordenar las notas de manera ascendente y descendente.
#
# Descripción: creo una serie de notas de 10 estudiantes, luego calculo la media, mediana, desviación y máxicmos. Por utlimo ordeno por notas

# %%
# todo:
[ ]


notas = pd.Series([4, 7, 5, 8, 6, 9, 3, 7, 10, 5])
print("Notas originales:")
print(notas)


media = notas.mean()
mediana = notas.median()
desviacion_std = notas.std()
maximo = notas.max()
print("\nEstadísticas:")
print(f"Media: {media}")
print(f"Mediana: {mediana}")
print(f"Desviación estándar: {desviacion_std}")
print(f"Máximo: {maximo}")

aprobados = notas[notas >= 6].count()
print(f"\nCantidad de aprobados (nota >= 6): {aprobados}")

notas_ascendente = notas.sort_values(ascending=True)
notas_descendente = notas.sort_values(ascending=False)
print("\nNotas ordenadas ascendente:")
print(notas_ascendente)
print("\nNotas ordenadas descendente:")
print(notas_descendente)
# Out:
# Notas originales:
# 0     4
# 1     7
# 2     5
# 3     8
# 4     6
# 5     9
# 6     3
# 7     7
# 8    10
# 9     5
# dtype: int64
#
# Estadísticas:
# Media: 6.4
# Mediana: 6.5
# Desviación estándar: 2.2211108331943574
# Máximo: 10
#
# Cantidad de aprobados (nota >= 6): 6
#
# Notas ordenadas ascendente:
# 6     3
# 0     4
# 2     5
# 9     5
# 4     6
# 7     7
# 1     7
# 3     8
# 5     9
# 8    10
# dtype: int64
#
# Notas ordenadas descendente:
# 8    10
# 5     9
# 3     8
# 1     7
# 7     7
# 4     6
# 9     5
# 2     5
# 0     4
# 6     3
# dtype: int64
